# %%
import pymatching
import sinter
from typing import List
import os
import numpy as np
import stim
import matplotlib.pyplot as plt
print(stim.__version__,os.cpu_count())
# Out:
# 1.15.0 12

# %%
circuit = stim.Circuit("""
    QUBIT_COORDS(0,0) 1
    QUBIT_COORDS(2,0) 2
    QUBIT_COORDS(3,0) 3
    QUBIT_COORDS(0,2) 4
    QUBIT_COORDS(2,2) 5
    QUBIT_COORDS(3,0) 6
    QUBIT_COORDS(3,3) 7
    QUBIT_COORDS(1,0) 8
    QUBIT_COORDS(0,1) 9
    QUBIT_COORDS(3,1) 10
    QUBIT_COORDS(3,2) 11
    QUBIT_COORDS(1,3) 12
    QUBIT_COORDS(2,3) 13
    R 1 2
    TICK
    H 9 11 13
    TICK
    CNOT 1 8
    TICK
""")
circuit.diagram("timeslice-svg")
# Out:
# <svg viewBox="0 0 739.2 739.2"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_dots">
# <circle id="qubit_dot:1:0_0:0" cx="80" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:0" cx="208" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:0" cx="272" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:0_2:0" cx="80" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:2_2:0" cx="208" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:3_0:0" cx="272" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:3_3:0" cx="272" cy="272" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:1_0:0" cx="144" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:0_1:0" cx="80" cy="144" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:3_1:0" cx="272" cy="144" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:11:3_2:0" cx="272" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:12:1_3:0" cx="144" cy="272" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:13:2_3:0" cx="208" cy="272" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:0_0:0" cx="80" cy="467.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:0" cx="208" cy="467.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:0" cx="272" cy="467.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:0_2:0" cx="80" cy="595.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:2_2:0" cx="208" cy="595.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:3_0:0" cx="272" cy="467.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:3_3:0" cx="272" cy="659.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:1_0:0" cx="144" cy="467.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:0_1:0" cx="80" cy="531.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:3_1:0" cx="272" cy="531.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:11:3_2:0" cx="272" cy="595.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:12:1_3:0" cx="144" cy="659.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:13:2_3:0" cx="208" cy="659.2" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:0_0:1" cx="467.2" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:1" cx="595.2" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:1" cx="659.2" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:0_2:1" cx="467.2" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:2_2:1" cx="595.2" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:3_0:1" cx="659.2" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:3_3:1" cx="659.2" cy="272" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:1_0:1" cx="531.2" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:0_1:1" cx="467.2" cy="144" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:3_1:1" cx="659.2" cy="144" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:11:3_2:1" cx="659.2" cy="208" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:12:1_3:1" cx="531.2" cy="272" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:13:2_3:1" cx="595.2" cy="272" r="2" stroke="none" fill="black"/>
# </g>
# <rect x="64" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="80" y="80" fill="white">R</text>
# <rect x="192" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="208" y="80" fill="white">R</text>
# <rect x="451.2" y="128" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="467.2" y="144">H</text>
# <rect x="643.2" y="192" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="659.2" y="208">H</text>
# <rect x="579.2" y="256" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="595.2" y="272">H</text>
# <path d="M80,467.2 L144,467.2 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="80" cy="467.2" r="12" stroke="none" fill="black"/>
# <circle cx="144" cy="467.2" r="12" stroke="black" fill="white"/>
# <path d="M132,467.2 L156,467.2 M144,455.2 L144,479.2 " stroke="black"/>
# <g id="tick_borders">
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="176" y="-346">Tick 0</text>
# <rect id="tick_border:0:0_0:0" x="0" y="0" width="352" height="352" stroke="black" fill="none"/>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="176" y="-733.2">Tick 1</text>
# <rect id="tick_border:1:0_1:1" x="387.2" y="0" width="352" height="352" stroke="black" fill="none"/>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="563.2" y="-346">Tick 2</text>
# <rect id="tick_border:2:1_0:2" x="0" y="387.2" width="352" height="352" stroke="black" fill="none"/>
# </g>
# </svg>
